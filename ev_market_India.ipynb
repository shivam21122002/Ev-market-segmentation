# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("EVIndia (1).csv")

# %%
data.head(10)
# Out:
#                      Car                  Style               Range  \
# 0          Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1          Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2      Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3               MG ZS EV            Compact SUV  419 Km/Full Charge
# 4  Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5          Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6         Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                 BYD E6         Subcompact MPV  415 Km/Full Charge
# 8      Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                 BMW iX   Premium Fullsize SUV  425 Km/Full Charge
#
#   Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0    Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1    Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# ...

# %%
data.shape
# Out:
# (12, 10)

# %%
data=data.drop("Capacity", axis='columns')

# %%
data
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
# ...

# %%
data1 = data.drop("Transmission", axis='columns')

# %%
data1
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    VehicleType         PriceRange BootSpace           BaseModel  \
# ...

# %%
data1.rename(columns={"Style": "Type"}, inplace=True)

# %%
data1.Type.duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# Name: Type, dtype: bool

# %%
data1.drop_duplicates(keep=False, inplace=True)

# %%
data1
# Out:
#                       Car                   Type               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    VehicleType         PriceRange BootSpace           BaseModel  \
# ...

# %%
data2=data1.drop("BootSpace", axis='columns')

# %%
data2.drop_duplicates(keep=False, inplace=True)

# %%
data2
# Out:
#                       Car                   Type               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
# ...

# %%
data2.reset_index(inplace=True, drop=True)

# %%
data2
# Out:
#                       Car                   Type               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
# ...

# %%
data2.shape
# Out:
# (12, 7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Car          12 non-null     object
#  1   Type         12 non-null     object
#  2   Range        12 non-null     object
#  3   VehicleType  12 non-null     object
#  4   PriceRange   12 non-null     object
#  5   BaseModel    12 non-null     object
#  6   TopModel     12 non-null     object
# dtypes: object(7)
# memory usage: 804.0+ bytes

# %%
data2['Type'].value_counts(sort=False).plot.bar()
# Out:
# <Axes: >

# %%
data2.plot.scatter(x = 'Type', y = 'Range', s = 100);

# %%
import matplotlib.pyplot as plt

# %%
Type = ['Compact SUV', 'Premium Midsize Sedan', 'Premium Fullsize SUV']
Range = [ 312, 306, 425]

# %%
plt.bar(Type, Range, color='green')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.xlabel("Type")
# Out:
# Text(0.5, 0, 'Type')

# %%
plt.bar(Type, Range, color='green')
plt.ylabel("Sales")
plt.title("EV Market Segmentation")
plt.show()

# %%
plt.pie(Range, labels=Type, autopct='%1.1f%%')
plt.title("EV Market Segmentation")
# Out:
# Text(0.5, 1.0, 'EV Market Segmentation')
